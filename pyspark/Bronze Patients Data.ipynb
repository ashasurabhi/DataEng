# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import current_timestamp , lit

# %%
spark = SparkSession.builder.appName("Spark SQL").getOrCreate()
df=spark.read.parquet("patients_raw.parquet")
df.printSchema()
df.show(5)
# Out:
# root
#  |-- patient_id: string (nullable = true)
#  |-- patient_name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- postcode: string (nullable = true)
#
# +----------+------------+---+------+--------+
# |patient_id|patient_name|age|gender|postcode|
# +----------+------------+---+------+--------+
# |  PAT_1000|Patient 1000| 29|Female|    2882|
# |  PAT_1001|Patient 1001| 45|     F|    2469|
# |  PAT_1002|Patient 1002| 42|     F|    2591|
# |  PAT_1003|Patient 1003| 48|  Male|    2506|
# |  PAT_1004|Patient 1004| 44|     F|    2658|
# +----------+------------+---+------+--------+
# only showing top 5 rows

# %%
patients = df \
    .withColumn("ingested_at", current_timestamp()) \
    .withColumn("source_file", lit("patients_raw.parquet"))
